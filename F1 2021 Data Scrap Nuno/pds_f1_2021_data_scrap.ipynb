# %% [markdown]
# # F1 2021 Data Sets

# %%
#Libraries
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request

# %% [markdown]
# ### 2021 race results

# %%
source = urllib.request.urlopen('https://www.formula1.com/en/results.html/2021/races.html').read()
soup = BeautifulSoup(source,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df.drop(["Unnamed: 0","Unnamed: 7"],axis=1, inplace=True)
df.head(50)
# Out:
#         Grand Prix         Date                Winner                    Car  \
# 0          Bahrain  28 Mar 2021    Lewis Hamilton HAM               Mercedes
# 1   Emilia Romagna  18 Apr 2021    Max Verstappen VER  Red Bull Racing Honda
# 2         Portugal  02 May 2021    Lewis Hamilton HAM               Mercedes
# 3            Spain  09 May 2021    Lewis Hamilton HAM               Mercedes
# 4           Monaco  23 May 2021    Max Verstappen VER  Red Bull Racing Honda
# 5       Azerbaijan  06 Jun 2021      Sergio Perez PER  Red Bull Racing Honda
# 6           France  20 Jun 2021    Max Verstappen VER  Red Bull Racing Honda
# 7           Styria  27 Jun 2021    Max Verstappen VER  Red Bull Racing Honda
# 8          Austria  04 Jul 2021    Max Verstappen VER  Red Bull Racing Honda
# 9    Great Britain  18 Jul 2021    Lewis Hamilton HAM               Mercedes
# 10         Hungary  01 Aug 2021      Esteban Ocon OCO         Alpine Renault
# 11         Belgium  29 Aug 2021    Max Verstappen VER  Red Bull Racing Honda
# 12     Netherlands  05 Sep 2021    Max Verstappen VER  Red Bull Racing Honda
# 13           Italy  12 Sep 2021  Daniel Ricciardo RIC       McLaren Mercedes
# 14          Russia  26 Sep 2021    Lewis Hamilton HAM               Mercedes
# 15          Turkey  10 Oct 2021   Valtteri Bottas BOT               Mercedes
# 16   United States  24 Oct 2021    Max Verstappen VER  Red Bull Racing Honda
# 17          Mexico  07 Nov 2021    Max Verstappen VER  Red Bull Racing Honda
# 18          Brazil  14 Nov 2021    Lewis Hamilton HAM               Mercedes
# 19           Qatar  21 Nov 2021    Lewis Hamilton HAM               Mercedes
# 20    Saudi Arabia  05 Dec 2021    Lewis Hamilton HAM               Mercedes
# 21       Abu Dhabi  12 Dec 2021    Max Verstappen VER  Red Bull Racing Honda
#
#     Laps         Time
# 0     56  1:32:03.897
# 1     63  2:02:34.598
# 2     66  1:34:31.421
# 3     66  1:33:07.680
# 4     78  1:38:56.820
# 5     51  2:13:36.410
# 6     53  1:27:25.770
# 7     71  1:22:18.925
# 8     71  1:23:54.543
# 9     52  1:58:23.284
# 10    70  2:04:43.199
# 11     1  0:03:27.071
# 12    72  1:30:05.395
# 13    53  1:21:54.365
# 14    53  1:30:41.001
# 15    58  1:31:04.103
# 16    56  1:34:36.552
# 17    71  1:38:39.086
# 18    71  1:32:22.851
# 19    57  1:24:28.471
# 20    50  2:06:15.118
# 21    58  1:30:17.345

# %% [markdown]
# ### 2021 Driver Standings

# %%
source = urllib.request.urlopen('https://www.formula1.com/en/results.html/2021/drivers.html').read()
soup = BeautifulSoup(source,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df.drop(["Unnamed: 0","Unnamed: 6"],axis=1, inplace=True)
df.head()
# Out:
#    Pos               Driver Nationality                    Car    PTS
# 0    1   Max Verstappen VER         NED  Red Bull Racing Honda  395.5
# 1    2   Lewis Hamilton HAM         GBR               Mercedes  387.5
# 2    3  Valtteri Bottas BOT         FIN               Mercedes  226.0
# 3    4     Sergio Perez PER         MEX  Red Bull Racing Honda  190.0
# 4    5     Carlos Sainz SAI         ESP                Ferrari  164.5

# %% [markdown]
# ### 2021 Constructor Standings

# %%
source = urllib.request.urlopen('https://www.formula1.com/en/results.html/2021/team.html').read()
soup = BeautifulSoup(source,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df.drop(["Unnamed: 0","Unnamed: 4"],axis=1, inplace=True)
df.head(20)
# Out:
#    Pos                       Team    PTS
# 0    1                   Mercedes  613.5
# 1    2      Red Bull Racing Honda  585.5
# 2    3                    Ferrari  323.5
# 3    4           McLaren Mercedes  275.0
# 4    5             Alpine Renault  155.0
# 5    6           AlphaTauri Honda  142.0
# 6    7      Aston Martin Mercedes   77.0
# 7    8          Williams Mercedes   23.0
# 8    9  Alfa Romeo Racing Ferrari   13.0
# 9   10               Haas Ferrari    0.0

# %% [markdown]
# ### 2021 DHL FASTEST LAP AWARD

# %%
source = urllib.request.urlopen('https://www.formula1.com/en/results.html/2021/fastest-laps.html').read()
soup = BeautifulSoup(source,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df.drop(['Unnamed: 0','Unnamed: 5'],axis=1, inplace=True)
df.head()
# Out:
#        Grand Prix               Driver                    Car      Time
# 0         Bahrain  Valtteri Bottas BOT               Mercedes  1:32.090
# 1  Emilia Romagna   Lewis Hamilton HAM               Mercedes  1:16.702
# 2        Portugal  Valtteri Bottas BOT               Mercedes  1:19.865
# 3           Spain   Max Verstappen VER  Red Bull Racing Honda  1:18.149
# 4          Monaco   Lewis Hamilton HAM               Mercedes  1:12.909

# %% [markdown]
# ### F1 Calendar - 2021

# %%
source = urllib.request.urlopen('https://www.espn.com/f1/schedule/_/year/2021').read()
soup = BeautifulSoup(source,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df.head()
# Out:
#              Date                                             Race  \
# 0     Mar 26 - 28          Bahrain GPBahrain International Circuit
# 1     Apr 16 - 18   Emilia Romagna GPAutodromo Enzo e Dino Ferrari
# 2  Apr 30 - May 2  Portuguese GPAutódromo Internacional Do Algarve
# 3       May 7 - 9         Spanish GPCircuit de Barcelona-Catalunya
# 4     May 20 - 23                       Monaco GPCircuit de Monaco
#
#   Winner/Lights Out          TV
# 0       L. Hamilton  Highlights
# 1     M. Verstappen  Highlights
# 2       L. Hamilton  Highlights
# 3       L. Hamilton  Highlights
# 4     M. Verstappen  Highlights

# %% [markdown]
# ### 2021 - Portuguese grand prix

# %% [markdown]
# ##### RACE CLASSIFICATION

# %%
source = urllib.request.urlopen('https://www.fia.com/events/fia-formula-one-world-championship/season-2021/portuguese-grand-prix/race-classification').read()
soup = BeautifulSoup(source,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df.head()
# Out:
#   RACE - CLASSIFICATION RACE - CLASSIFICATION.1  \
# 0                   POS                  DRIVER
# 1                     1          Lewis Hamilton
# 2                     2          Max Verstappen
# 3                     3         Valtteri Bottas
# 4                     4            Sergio Perez
#
#          RACE - CLASSIFICATION.2 RACE - CLASSIFICATION.3  \
# 0                           TEAM                    LAPS
# 1  Mercedes-AMG Petronas F1 Team                      66
# 2          Red Bull Racing Honda                      66
# 3  Mercedes-AMG Petronas F1 Team                      66
# 4          Red Bull Racing Honda                      66
#
#   RACE - CLASSIFICATION.4  RACE - CLASSIFICATION.5
# 0                    TIME                      NaN
# 1             1:34:31.421                      NaN
# 2             1:35:00.569                      NaN
# 3             1:35:04.951                      NaN
# 4             1:35:11.156                      NaN

# %% [markdown]
# RACE - FASTEST LAPS

# %%
source = urllib.request.urlopen('https://www.fia.com/events/fia-formula-one-world-championship/season-2021/portuguese-grand-prix/race-classification').read()
soup = BeautifulSoup(source,'lxml')
table = soup.find_all('table')[1] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df.head()
# Out:
#   RACE - FASTEST LAPS RACE - FASTEST LAPS.1 RACE - FASTEST LAPS.2  \
# 0                 POS                DRIVER              LAP TIME
# 1                   1       Valtteri Bottas              1:19.865
# 2                   2          Sergio Perez              1:20.643
# 3                   3        Max Verstappen              1:20.695
# 4                   4        Lewis Hamilton              1:20.933
#
#   RACE - FASTEST LAPS.3 RACE - FASTEST LAPS.4 RACE - FASTEST LAPS.5  \
# 0                   LAP                   GAP                  KM/H
# 1                    65               +00.000               209.738
# 2                    55               +00.778               207.715
# 3                    62               +00.830               207.581
# 4                    47               +01.068               206.971
#
#   RACE - FASTEST LAPS.6  RACE - FASTEST LAPS.7  RACE - FASTEST LAPS.8
# 0                  TIME                    NaN                    NaN
# 1              16:36:46                    NaN                    NaN
# 2              16:23:11                    NaN                    NaN
# 3              16:32:12                    NaN                    NaN
# 4              16:11:48                    NaN                    NaN

# %% [markdown]
# RACE - BEST SECTOR TIMES

# %%
table = soup.find_all('table')[2] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df.head()
# Out:
#   RACE - BEST SECTOR TIMES RACE - BEST SECTOR TIMES.1  \
# 0                      NaN                   SECTOR 1
# 1                      POS                     DRIVER
# 2                        1               K. Raikkonen
# 3                        2              M. Verstappen
# 4                        3                L. Hamilton
#
#   RACE - BEST SECTOR TIMES.2 RACE - BEST SECTOR TIMES.3  \
# 0                   SECTOR 1                   SECTOR 2
# 1                       TIME                     DRIVER
# 2                     00.000                  V. Bottas
# 3                     23.186              M. Verstappen
# 4                     23.319                   S. Perez
#
#   RACE - BEST SECTOR TIMES.4 RACE - BEST SECTOR TIMES.5  \
# 0                   SECTOR 2                   SECTOR 3
# 1                       TIME                     DRIVER
# 2                     30.617                  V. Bottas
# 3                     30.658              M. Verstappen
# 4                     30.895                L. Hamilton
#
#   RACE - BEST SECTOR TIMES.6  RACE - BEST SECTOR TIMES.7
# 0                   SECTOR 3                         NaN
# 1                       TIME                         NaN
# 2                     25.892                         NaN
# 3                     26.005                         NaN
# 4                     26.060                         NaN

# %% [markdown]
# RACE - SPEED TRAP

# %%
table = soup.find_all('table')[3] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df.head()
# Out:
#   RACE - SPEED TRAP RACE - SPEED TRAP.1             RACE - SPEED TRAP.2  \
# 0               POS              DRIVER                            TEAM
# 1                 1        Esteban Ocon                  Alpine F1 Team
# 2                 2        Yuki Tsunoda       Scuderia AlphaTauri Honda
# 3                 3    Sebastian Vettel  Aston Martin Cognizant F1 Team
# 4                 4     Nicholas Latifi                 Williams Racing
#
#   RACE - SPEED TRAP.3 RACE - SPEED TRAP.4  RACE - SPEED TRAP.5
# 0                KM/H                TIME                  NaN
# 1               333.1                   -                  NaN
# 2               332.4                   -                  NaN
# 3               329.2                   -                  NaN
# 4               329.1                   -                  NaN

# %% [markdown]
# RACE - MAXIMUM SPEEDS

# %%
table = soup.find_all('table')[4] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df.head()
# Out:
#   RACE - MAXIMUM SPEEDS RACE - MAXIMUM SPEEDS.1 RACE - MAXIMUM SPEEDS.2  \
# 0                   NaN          INTERMEDIATE 1          INTERMEDIATE 1
# 1                   POS                  DRIVER                    KM/H
# 2                     1                P. Gasly                   292.0
# 3                     2                C. Sainz                   289.9
# 4                     3              Y. Tsunoda                   288.6
#
#   RACE - MAXIMUM SPEEDS.3 RACE - MAXIMUM SPEEDS.4 RACE - MAXIMUM SPEEDS.5  \
# 0          INTERMEDIATE 2          INTERMEDIATE 2             FINISH LINE
# 1                  DRIVER                    KM/H                  DRIVER
# 2                 E. Ocon                   195.0               F. Alonso
# 3               S. Vettel                   194.5            K. Raikkonen
# 4               F. Alonso                   193.9                 E. Ocon
#
#   RACE - MAXIMUM SPEEDS.6  RACE - MAXIMUM SPEEDS.7
# 0             FINISH LINE                      NaN
# 1                    KM/H                      NaN
# 2                   307.5                      NaN
# 3                   306.0                      NaN
# 4                   305.2                      NaN

# %% [markdown]
# RACE - PIT STOP - SUMMARY

# %%
table = soup.find_all('table')[5] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20832/3967141312.py in <module>
# ----> 1 table = soup.find_all('table')[5]
#       2 df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
#       3 df.head()
#
# IndexError: list index out of range

# %% [markdown]
# ### Circuits

# %%
source = urllib.request.urlopen('https://simple.wikipedia.org/wiki/List_of_Formula_One_circuits').read()
soup = BeautifulSoup(source,'lxml')
table = soup.find_all('table')[1] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df.drop(["Map"],axis=1, inplace=True)
df
# Out:
#                     Circuit            Type        Location      Country  \
# 0   Adelaide Street Circuit  street circuit        Adelaide    Australia
# 1                  Ain-Diab    road circuit      Casablanca      Morocco
# 2                   Aintree    road circuit       Liverpool           UK
# 3               Albert Park  street circuit       Melbourne    Australia
# 4                      AVUS  street circuit          Berlin      Germany
# ..                      ...             ...             ...          ...
# 65             Watkins Glen    road circuit    Watkins Glen          USA
# 66       Yas Marina Circuit          hybrid       Abu Dhabi          UAE
# 67   Circuit Park Zandvoort    race circuit       Zandvoort  Netherlands
# 68         Zeltweg Airfield    road circuit         Zeltweg      Austria
# 69           Circuit Zolder    race circuit  Heusden-Zolder      Belgium
#
#                      Race(s)                                    Season(s)  \
# 0      Australian Grand Prix                                    1985–1995
# 1        Moroccan Grand Prix                                         1958
# 2         British Grand Prix                  1955, 1957, 1959, 1961–1962
# 3      Australian Grand Prix                                    1996–2020
# 4          German Grand Prix                                         1959
# ..                       ...                                          ...
# 65  United States Grand Prix                                    1961–1980
# 66      Abu Dhabi Grand Prix                                    2009–2020
# 67          Dutch Grand Prix  1952–1953, 1955, 1958–1971, 1973–1985, 2020
# 68       Austrian Grand Prix                                         1964
# 69        Belgian Grand Prix                        1973, 1975–1982, 1984
#
#     Races held
# 0         11.0
# 1          1.0
# 2          5.0
# 3         25.0
# 4          1.0
# ..         ...
# 65        20.0
# 66        11.0
# 67        30.0
# 68         1.0
# 69        10.0
#
# [70 rows x 7 columns]

# %%
source = urllib.request.urlopen('https://www.formula1.com/en/results.html/2021/races.html').read()
soup = BeautifulSoup(source,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df
# Out:
#     Unnamed: 0      Grand Prix         Date                Winner  \
# 0          NaN         Bahrain  28 Mar 2021    Lewis Hamilton HAM
# 1          NaN  Emilia Romagna  18 Apr 2021    Max Verstappen VER
# 2          NaN        Portugal  02 May 2021    Lewis Hamilton HAM
# 3          NaN           Spain  09 May 2021    Lewis Hamilton HAM
# 4          NaN          Monaco  23 May 2021    Max Verstappen VER
# 5          NaN      Azerbaijan  06 Jun 2021      Sergio Perez PER
# 6          NaN          France  20 Jun 2021    Max Verstappen VER
# 7          NaN          Styria  27 Jun 2021    Max Verstappen VER
# 8          NaN         Austria  04 Jul 2021    Max Verstappen VER
# 9          NaN   Great Britain  18 Jul 2021    Lewis Hamilton HAM
# 10         NaN         Hungary  01 Aug 2021      Esteban Ocon OCO
# 11         NaN         Belgium  29 Aug 2021    Max Verstappen VER
# 12         NaN     Netherlands  05 Sep 2021    Max Verstappen VER
# 13         NaN           Italy  12 Sep 2021  Daniel Ricciardo RIC
# 14         NaN          Russia  26 Sep 2021    Lewis Hamilton HAM
# 15         NaN          Turkey  10 Oct 2021   Valtteri Bottas BOT
# 16         NaN   United States  24 Oct 2021    Max Verstappen VER
# 17         NaN          Mexico  07 Nov 2021    Max Verstappen VER
# 18         NaN          Brazil  14 Nov 2021    Lewis Hamilton HAM
# 19         NaN           Qatar  21 Nov 2021    Lewis Hamilton HAM
# 20         NaN    Saudi Arabia  05 Dec 2021    Lewis Hamilton HAM
# 21         NaN       Abu Dhabi  12 Dec 2021    Max Verstappen VER
#
#                       Car  Laps         Time  Unnamed: 7
# 0                Mercedes    56  1:32:03.897         NaN
# 1   Red Bull Racing Honda    63  2:02:34.598         NaN
# 2                Mercedes    66  1:34:31.421         NaN
# 3                Mercedes    66  1:33:07.680         NaN
# 4   Red Bull Racing Honda    78  1:38:56.820         NaN
# 5   Red Bull Racing Honda    51  2:13:36.410         NaN
# 6   Red Bull Racing Honda    53  1:27:25.770         NaN
# 7   Red Bull Racing Honda    71  1:22:18.925         NaN
# 8   Red Bull Racing Honda    71  1:23:54.543         NaN
# 9                Mercedes    52  1:58:23.284         NaN
# 10         Alpine Renault    70  2:04:43.199         NaN
# 11  Red Bull Racing Honda     1  0:03:27.071         NaN
# 12  Red Bull Racing Honda    72  1:30:05.395         NaN
# 13       McLaren Mercedes    53  1:21:54.365         NaN
# 14               Mercedes    53  1:30:41.001         NaN
# 15               Mercedes    58  1:31:04.103         NaN
# 16  Red Bull Racing Honda    56  1:34:36.552         NaN
# 17  Red Bull Racing Honda    71  1:38:39.086         NaN
# 18               Mercedes    71  1:32:22.851         NaN
# 19               Mercedes    57  1:24:28.471         NaN
# 20               Mercedes    50  2:06:15.118         NaN
# 21  Red Bull Racing Honda    58  1:30:17.345         NaN

# %%
source = urllib.request.urlopen('https://www.espn.com/f1/results/_/id/600001741').read()
soup = BeautifulSoup(source,'lxml')
table = soup.find_all('table')
df = pd.read_html(str(table), flavor='bs4', header=[0])[0]
df
# Out:
#           SESSIONS RESULT         TIME
# 0  Free Practice 1    VER     1:31.394
# 1  Free Practice 2    VER     1:30.847
# 2  Free Practice 3    VER     1:30.577
# 3       Qualifying    VER     1:28.997
# 4             Race    HAM  1:32:03.897
