# %% [markdown]
# # Creating a map with F1 information

# %% [markdown]
# ## Circuits, Constructors and Drivers around the Globe

# %% [markdown]
# Installing the required modules

# %%
#pip install wikipedia
#pip install folium

# %%
import folium #module to create maps
import pandas as pd #data science module
import pyodbc #to connect to azure sql
from decimal import * #to handle wikipedia coordinates

# %%
import wikipedia as wiki

# %% [markdown]
# Connecting python to the Azure db.

# %%
server = 'f1server.database.windows.net'
database = 'WackyRacesF1'
username = 'PDS'
password = '{Formula1}'   
driver= '{ODBC Driver 17 for SQL Server}'

# %% [markdown]
# Running SQL queries using Python to import the required information into Pandas dataframes.

# %%
cnxn = pyodbc.connect('DRIVER='+driver+';SERVER=tcp:'+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()
constructors_query = "SELECT DISTINCT c.constructorId, constructorRef, c.name, nationality, c.url FROM constructors c LEFT JOIN constructorResults cr ON c.constructorId = cr.constructorId LEFT JOIN races r ON r.raceId = cr.raceId WHERE year >= 2015 and year <= 2022;"
constructors = pd.read_sql(constructors_query, cnxn)
circuits_query = "SELECT DISTINCT c.circuitId, c.name, c.location, c.country, lat, lng, alt, c.url FROM circuits c LEFT JOIN races r ON r.circuitId = c.circuitId WHERE year >= 2015 and year <= 2022;"
circuits = pd.read_sql(circuits_query, cnxn)

# %% [markdown]
# Importing csv with information on drivers into an additional Pandas dataframe.

# %%
drivers = pd.read_excel('f1_drivers_2015_2021.xlsx')

# %% [markdown]
# ### Creating functions to extract information from wikipedia

# %%
def get_wiki_summary(df):
    summary = []

    for name in df:
        try:
            detail = wiki.WikipediaPage(title=name).summary
            summary.append(detail)
        except:
            if name == "Williams":
                summary.append("Williams Grand Prix Engineering Limited, currently racing in Formula One as Williams Racing, is a British Formula One motor racing team and constructor. It was founded by former team owner Frank Williams and automotive engineer Patrick Head. The team was formed in 1977 after Frank Williams's earlier unsuccessful F1 operation: Frank Williams Racing Cars (which later became Wolf–Williams Racing in 1976). All of Williams F1 chassis are called 'FW' then a number, the FW being the initials of team co-founder and original owner, Frank Williams.")
            elif name == "Mercedes":
                summary.append("Mercedes-Benz, a brand of the Mercedes-Benz Group, has been involved in Formula One as both team owner and engine manufacturer for various periods since 1954. The Mercedes-AMG Petronas F1 Team, which is based in Brackley, England, and possesses a German licence, is as of 2022 majority owned by the Mercedes-Benz Group with Toto Wolff having a significant shareholding. Mercedes-branded teams are often referred to by the nickname, the 'Silver Arrows'. An announcement was made in December 2020 that Ineos planned to take a one third equal ownership stake alongside the Mercedes-Benz Group and Wolff; this came into effect on 25 January 2022.")
            elif name == "AlphaTauri":
                summary.append("Scuderia AlphaTauri, or simply AlphaTauri, is an Italian Formula One racing team and constructor. It is one of two Formula One constructors owned by Austrian beverage company Red Bull, the other being Red Bull Racing. The constructor was rebranded for the 2020 Formula One World Championship from 'Toro Rosso' to 'AlphaTauri' in order to promote the AlphaTauri fashion brand. According to Franz Tost and Helmut Marko, Scuderia AlphaTauri is no longer the junior team but the sister team to Red Bull Racing.")
            else:
                summary.append('error')
                print(name)
        
    return summary

# %%
def get_coords(df):
    lat = []
    long = []

    for name in df:
        try:
            coord = wiki.WikipediaPage(title=name).coordinates
            lat.append(coord[0])
            long.append(coord[1])
        except:
            if name == "Nürburgring": #to account for the Nürburgring
                lat.append(Decimal('50.57469354557302'))
                long.append(Decimal('7.045744986271267'))
            elif name == "Miami International Autodrome": #to account for the Miami International Autodrome
                lat.append(Decimal('25.95717260961372'))
                long.append(Decimal('-80.231329321313'))
            elif name == "Netherlands": #to account for the Netherlands
                lat.append(Decimal('52.36463903490765')) 
                long.append(Decimal('4.908115191408701'))
            elif name == "Russia": #to account for Russia
                lat.append(Decimal('55.802479274214974'))
                long.append(Decimal('37.592885102145694'))
            else:
                lat.append(Decimal('3'))
                long.append(Decimal('4'))
                print(name)
                
    return lat, long

# %%
def generate_map(circuits, drivers, constructor):
    
    my_map = folium.Map(location=[38.73241897525329, -9.160338893258317], #the coordinates to Nova IMS serve as the initial focal point for the map
                    zoom_start=2,
                    tiles='CartoDB dark_matter',
                    attr='João Rodrigues, Nuno Lopes, Ricardo Almeida, Soraia Alves, Teresa Barrosa'
                   )
    
    #inputting circuit information into the map
    for index, row in circuits.iterrows():
        
        html=f"""
        <h1><img src='data:image/svg+xml;base64,...'/></p>
        </h1>
        <h1><p> {row['name']}</p></h1>
        <p><p>Circuit information:</p>
        <ul>
            <li>Country name: {row['country']}</li>
            <li>City name: {row['location']}</li>
        <details>
            <summary>More details</summary>
            {row['summary']}
        </details>     
        </ul>
        </p>
        <p>To know more: <a href={row['url']}>link</a></p>
        """
        
        iframe = folium.IFrame(html=html, width=300, height=300)
        
        popup = folium.Popup(iframe, max_width=2650)
        
        folium.Marker(location=[row['lat'],row['long']],popup=popup,tooltip=row['name'],radius=3, icon=folium.Icon(color='red')).add_to(my_map)
        
    #inputting drivers information into the map
    for index, row in drivers.iterrows():
        
        html=f"""
        <h1><img src='data:image/svg+xml;base64,...'/></p>
        </h1>
        <h1><p> {row['DRIVER']}</p></h1>
        <p><p>Driver information:</p>
        <ul>
            <li>Country name: {row['COUNTRY']}</li>
        <details>
            <summary>More details</summary>
            {row['SUMMARY']}
        </details>     
        </ul>
        </p>
        """
        
        iframe = folium.IFrame(html=html, width=300, height=300)
        
        popup = folium.Popup(iframe, max_width=2650)
        
        folium.Marker(location=[row['lat'],row['long']],popup=popup,tooltip=row['SUMMARY'],radius=3, color='red').add_to(my_map)
        
        #inputting constructor information into the map
    for index, row in constructor.iterrows():
        
        html=f"""
        <h1><img src='data:image/svg+xml;base64,...'/></p>
        </h1>
        <h1><p> {row['name']}</p></h1>
        <p><p>Constructor information:</p>
        <ul>
            <li>Country name: {row['country']}</li>
        <details>
            <summary>More details</summary>
            {row['summary']}
        </details>     
        </ul>
        </p>
        """
        
        iframe = folium.IFrame(html=html, width=300, height=300)
        
        popup = folium.Popup(iframe, max_width=2650)
        
        folium.Marker(location=[row['lat'],row['long']],popup=popup,tooltip=row['summary'],radius=3, icon=folium.Icon(color='white')).add_to(my_map)

        
    return my_map

# %% [markdown]
# ## Driver information

# %%
drivers
# Out:
#     DRIVER_ID              DRIVER         DRIVER_REF DRIVER_CODE        DOB  \
# 0           1      Lewis Hamilton           hamilton         HAM 1985-01-07
# 1           3        Nico Rosberg            rosberg         ROS 1985-06-27
# 2           4     Fernando Alonso             alonso         ALO 1981-07-29
# 3           8      Kimi Raikkonen          raikkonen         RAI 1979-10-17
# 4           9       Robert Kubica             kubica         KUB 1984-12-07
# 5          13        Felipe Massa              massa         MAS 1981-04-25
# 6          16        Adrian Sutil              sutil         SUT 1983-01-11
# 7          18       Jenson Button             button         BUT 1980-01-19
# 8          20    Sebastian Vettel             vettel         VET 1987-07-03
# 9         154     Romain Grosjean           grosjean         GRO 1986-04-17
# 10        155     Kamui Kobayashi          kobayashi         KOB 1986-09-13
# 11        807     Nico Hulkenberg         hulkenberg         HUL 1987-08-19
# 12        813    Pastor Maldonado          maldonado         MAL 1985-03-09
# 13        815        Sergio Perez              perez         PER 1990-01-26
# 14        817    Daniel Ricciardo          ricciardo         RIC 1989-07-01
# 15        818    Jean-Eric Vergne             vergne         VER 1990-04-25
# 16        820         Max Chilton            chilton         CHI 1991-04-21
# 17        821   Esteban Gutierrez          gutierrez         GUT 1991-08-05
# 18        822     Valtteri Bottas             bottas         BOT 1989-08-28
# 19        824       Jules Bianchi      jules_bianchi         BIA 1989-08-03
# 20        825     Kevin Magnussen    kevin_magnussen         MAG 1992-10-05
# 21        826        Daniil Kvyat              kvyat         KVY 1994-04-26
# 22        827      André Lotterer           lotterer         LOT 1981-11-19
# 23        828     Marcus Ericsson           ericsson         ERI 1990-09-02
# 24        829        Will Stevens            stevens         STE 1991-06-28
# 25        830      Max Verstappen     max_verstappen         VER 1997-09-30
# 26        831         Felipe Nasr               nasr         NAS 1992-08-21
# 27        832    Carlos Sainz Jr.              sainz         SAI 1994-09-01
# 28        833       Roberto Merhi              merhi         MER 1991-03-22
# 29        834     Alexander Rossi              rossi         RSS 1991-09-25
# 30        835       Jolyon Palmer      jolyon_palmer         PAL 1991-01-20
# 31        836     Pascal Wehrlein           wehrlein         WEH 1994-10-18
# 32        837        Rio Haryanto           haryanto         HAR 1993-01-22
# 33        838   Stoffel Vandoorne          vandoorne         VAN 1992-03-26
# 34        839        Esteban Ocon               ocon         OCO 1996-09-17
# 35        840        Lance Stroll             stroll         STR 1998-10-29
# 36        841  Antonio Giovinazzi         giovinazzi         GIO 1993-12-14
# 37        842        Pierre Gasly              gasly         GAS 1996-02-07
# 38        843     Brendon Hartley    brendon_hartley         HAR 1989-11-10
# 39        844     Charles Leclerc            leclerc         LEC 1997-10-16
# 40        845     Sergey Sirotkin           sirotkin         SIR 1995-08-27
# 41        846        Lando Norris             norris         NOR 1999-11-13
# 42        847      George Russell            russell         RUS 1998-02-15
# 43        848     Alexander Albon              albon         ALB 1996-03-23
# 44        849     Nicholas Latifi             latifi         LAT 1995-06-29
# 45        850   Pietro Fittipaldi  pietro_fittipaldi         FIT 1996-06-25
# 46        851         Jack Aitken             aitken         AIT 1995-09-23
# 47        852        Yuki Tsunoda            tsunoda         TSU 2000-05-11
# 48        853      Nikita Mazepin            mazepin         MAZ 1999-03-02
# 49        854     Mick Schumacher    mick_schumacher         MSC 1999-03-22
# 50        855         Guanyu Zhou               zhou         ZHO 1999-05-30
#
#       NATIONALITY         COUNTRY  \
# 0         British  United Kingdom
# 1          German         Germany
# 2         Spanish           Spain
# 3         Finnish         Finland
# 4          Polish          Poland
# 5       Brazilian          Brazil
# 6          German         Germany
# 7         British  United Kingdom
# 8          German         Germany
# 9          French          France
# 10       Japanese           Japan
# 11         German         Germany
# 12     Venezuelan       Venezuela
# 13        Mexican          Mexico
# 14     Australian       Australia
# 15         French          France
# 16        British  United Kingdom
# 17        Mexican          Mexico
# 18        Finnish         Finland
# 19         French          France
# 20         Danish         Denmark
# 21        Russian          Russia
# 22         German         Germany
# 23        Swedish          Sweden
# 24        British  United Kingdom
# 25          Dutch     Netherlands
# 26      Brazilian          Brazil
# 27        Spanish           Spain
# 28        Spanish           Spain
# 29       American   United States
# 30        British  United Kingdom
# 31         German         Germany
# 32     Indonesian       Indonesia
# 33        Belgian         Belgium
# 34         French          France
# 35       Canadian          Canada
# 36        Italian    Vatican City
# 37         French          France
# 38  New Zealander     New Zealand
# 39     Monegasque          Monaco
# 40        Russian          Russia
# 41        British  United Kingdom
# 42        British  United Kingdom
# 43           Thai        Thailand
# 44       Canadian          Canada
# 45      Brazilian          Brazil
# 46        British  United Kingdom
# 47       Japanese           Japan
# 48        Russian          Russia
# 49         German         Germany
# 50        Chinese           China
#
#                                               SUMMARY  \
# 0   Sir Lewis Carl Davidson Hamilton  (born 7 Janu...
# 1   Nico Erik Rosberg (born 27 June 1985) is a Ger...
# 2   Fernando Alonso Díaz (Spanish pronunciation: [...
# 3   Kimi-Matias Räikkönen (Finnish pronunciation: ...
# 4   Robert Józef Kubica (Polish pronunciation: [ˈr...
# 5   Felipe Massa (Portuguese pronunciation: [fiˈli...
# 6   Adrian Sutil (German pronunciation: [ˈadɾjan z...
# 7   Jenson Alexander Lyons Button  (born 19 Januar...
# 8   Sebastian Vettel (German pronunciation: [zeˈba...
# 9   Romain Grosjean (French: [ʁɔmɛ̃ ɡʁoʒɑ̃]; born ...
# 10  Kamui Kobayashi (小林 可夢偉, Kobayashi Kamui, born...
# 11  Nicolas Hülkenberg (German pronunciation: [ˈni...
# 12  Pastor Rafael Maldonado Motta (Spanish pronunc...
# 13  Sergio Michel "Checo" Pérez Mendoza (Spanish: ...
# 14  Daniel Joseph Ricciardo  ( "Ricardo"; born 1 J...
# 15  Jean-Éric Vergne (born 25 April 1990), also kn...
# 16  Maximilian Alexander Chilton (born 21 April 19...
# 17  Esteban Manuel Gutiérrez Gutiérrez (Spanish pr...
# 18  Valtteri Viktor Bottas (Finnish pronunciation:...
# 19  Jules Lucien André Bianchi (French pronunciati...
# 20  Kevin Jan Magnussen (born 5 October 1992) is a...
# 21  Daniil Vyacheslavovich Kvyat (born 26 April 19...
# 22  André Lotterer (born 19 November 1981) is a Ge...
# 23  Marcus Thorbjörn Ericsson (Swedish pronunciati...
# 24  William Stevens (born 28 June 1991) is a Briti...
# 25  Max Emilian Verstappen (born 30 September 1997...
# 26  Luiz Felipe de Oliveira Nasr (born 21 August 1...
# 27  Carlos Sainz Vázquez de Castro (Spanish pronun...
# 28  Roberto Merhi Muntan (born 22 March 1991) is a...
# 29  Alexander Michael Rossi (born September 25, 19...
# 30  Jolyon Palmer (born 20 January 1991) is a Brit...
# 31  Pascal Wehrlein (born 18 October 1994) is a Ge...
# 32  Rio Haryanto (born 22 January 1993) is an Indo...
# 33  Stoffel Vandoorne (born 26 March 1992) is a Be...
# 34  Esteban José Jean-Pierre Ocon-Khelfane (born 1...
# 35  Lance Strulovitch, (born 29 October 1998) bett...
# 36  Antonio Maria Giovinazzi (Italian pronunciatio...
# 37  Pierre Gasly (French pronunciation: ​[pjɛʁ ɡas...
# 38  Brendon Hartley (born 10 November 1989) is a N...
# 39  Charles Marc Hervé Perceval Leclerc (French pr...
# 40  Sergey Olegovich Sirotkin (Russian: Серге́й Ол...
# 41  Lando Norris (; born 13 November 1999) is a Br...
# 42                                              error
# 43  Alexander Albon Ansusinha (Thai: อเล็กซานเดอร์...
# 44  Nicholas Daniel Latifi (born 29 June 1995) is ...
# 45  Pietro Fittipaldi da Cruz (born 25 June 1996) ...
# 46  Jack Aitken (Korean: 한세용, Han Se-yong; born 23...
# 47  Yuki Tsunoda (Japanese: 角田 裕毅, Tsunoda Yūki; b...
# 48  Nikita Dmitryevich Mazepin (Russian: Ники́та Д...
# 49  Mick Schumacher (German pronunciation: [ˈmɪk ˈ...
# 50  Zhou Guanyu (Chinese: 周冠宇; pinyin: Zhōu Guànyǔ...
#
#                                                   lat  \
# 0                                                  55
# 1                                                  51
# 2                                                  40
# 3                                                  64
# 4                                                  52
# 5                                                 -10
# 6                                                  51
# 7                                                  55
# 8                                                  51
# 9                                                  47
# 10                                                 36
# 11                                                 51
# 12                                                  7
# 13                                                 23
# 14                                                -25
# 15                                                 47
# 16                                                 55
# 17                                                 23
# 18                                                 64
# 19                                                 47
# 20                                                 56
# 21                                 55.802479274214974
# 22                                                 51
# 23                                                 63
# 24                                                 55
# 25                                  52.36463903490765
# 26                                                -10
# 27                                                 40
# 28                                                 40
# 29                                                 40
# 30                                                 55
# 31                                                 51
# 32                                                 -5
# 33  50.8333333300000020926745492033660411834716796875
# 34                                                 47
# 35                                                 60
# 36   41.902500000000003410605131648480892181396484375
# 37                                                 47
# 38                                                -42
# 39   43.731111110000000508080120198428630828857421875
# 40                                 55.802479274214974
# 41                                                 55
# 42                                                 55
# 43                                                 15
# 44                                                 60
# 45                                                -10
# 46                                                 55
# 47                                                 36
# 48                                 55.802479274214974
# 49                                                 51
# 50                                                 35
#
#                                                  long
# 0                                                  -3
# 1                                                   9
# 2                                                  -4
# 3                                                  26
# 4                                                  20
# 5                                                 -52
# 6                                                   9
# 7                                                  -3
# 8                                                   9
# 9                                                   2
# 10                                                138
# 11                                                  9
# 12                                                -65
# 13                                               -102
# 14                                                133
# 15                                                  2
# 16                                                 -3
# 17                                               -102
# 18                                                 26
# 19                                                  2
# 20                                                 10
# 21                                 37.592885102145694
# 22                                                  9
# 23                                                 16
# 24                                                 -3
# 25                                  4.908115191408701
# 26                                                -52
# 27                                                 -4
# 28                                                 -4
# 29                                               -100
# 30                                                 -3
# 31                                                  9
# 32                                                120
# 33                                                  4
# 34                                                  2
# 35                                               -110
# 36  12.4525000000000005684341886080801486968994140625
# 37                                                  2
# 38                                                173
# 39  7.41999999999999992894572642398998141288757324...
# 40                                 37.592885102145694
# 41                                                 -3
# 42                                                 -3
# 43                                                101
# 44                                               -110
# 45                                                -52
# 46                                                 -3
# 47                                                138
# 48                                 37.592885102145694
# 49                                                  9
# 50                                                103

# %% [markdown]
# We need geographical data on the drivers, as well as a short contextualization of who they are to display on the map.

# %%
drivers['COUNTRY'] = drivers['NATIONALITY'].replace({'Andorran':'Andorra','Emirati':'United Arab Emirates','Afghan':'Afghanistan','Antiguan, Barbudan':'Antigua and Barbuda','Anguillian':'Anguilla','Albanian':'Albania','Armenian':'Armenia','Dutch':'Netherlands Antilles','Angolan':'Angola','???':'Antarctica','Argentinean':'Argentina','American Samoan':'American Samoa','Austrian':'Austria','Australian':'Australia','Aruban':'Aruba','Swedish':'Åland Islands','Azerbaijani':'Azerbaijan','Bosnian, Herzegovinian':'Bosnia and Herzegovina','Barbadian':'Barbados','Bangladeshi':'Bangladesh','Belgian':'Belgium','Burkinabe':'Burkina Faso','Bulgarian':'Bulgaria','Bahraini':'Bahrain','Burundian':'Burundi','Beninese':'Benin','Saint Barthélemy Islander':'Saint Barthélemy','Bermudian':'Bermuda','Bruneian':'Brunei','Bolivian':'Bolivia','Dutch':'British Antarctic Territory','Brazilian':'Brazil','Bahamian':'Bahamas','Bhutanese':'Bhutan','???':'Bouvet Island','Motswana':'Botswana','Belarusian':'Belarus','Belizean':'Belize','Canadian':'Canada','Cocos Islander':'Cocos [Keeling] Islands','Congolese':'Congo - Kinshasa','Central African':'Central African Republic','Congolese':'Congo - Brazzaville','Swiss':'Switzerland','Ivorian':'Côte d’Ivoire','Cook Islander':'Cook Islands','Chilean':'Chile','Cameroonian':'Cameroon','Chinese':'China','Colombian':'Colombia','Costa Rican':'Costa Rica','Montenegrins, Serbs':'Serbia and Montenegro','???':'Canton and Enderbury Islands','Cuban':'Cuba','Cape Verdian':'Cape Verde','Curaçaoan':'Curaçao','Christmas Island':'Christmas Island','Cypriot':'Cyprus','Czech':'Czech Republic','German':'Germany','Djibouti':'Djibouti','Danish':'Denmark','Dominican':'Dominica','Dominican':'Dominican Republic','Algerian':'Algeria','Ecuadorean':'Ecuador','Estonian':'Estonia','Egyptian':'Egypt','Sahrawi':'Western Sahara','Eritrean':'Eritrea','Spanish':'Spain','Ethiopian':'Ethiopia','Finnish':'Finland','Fijian':'Fiji','Falkland Islander':'Falkland Islands','Micronesian':'Micronesia','Faroese':'Faroe Islands','???':'French
'Palestinian Territories','Portuguese':'Portugal','???':'U.S. Miscellaneous Pacific Islands','Palauan':'Palau','Paraguayan':'Paraguay','???':'Panama Canal Zone','Qatari':'Qatar','French':'Réunion','Romanian':'Romania','Serbian':'Serbia','Russian':'Russia','Rwandan':'Rwanda','Saudi Arabian':'Saudi Arabia','Solomon Islander':'Solomon Islands','Seychellois':'Seychelles','Sudanese':'Sudan','Swedish':'Sweden','Singaporean':'Singapore','Saint Helenian':'Saint Helena','Slovene':'Slovenia','Norwegian':'Svalbard and Jan Mayen','Slovak':'Slovakia','Sierra Leonean':'Sierra Leone','Sammarinese':'San Marino','Senegalese':'Senegal','Somali':'Somalia','Surinamer':'Suriname','Sao Tomean':'São Tomé and Príncipe','???':'Union of Soviet Socialist Republics','Salvadoran':'El Salvador','Syrian':'Syria','Swazi':'Swaziland','Turks and Caicos Islander':'Turks and Caicos Islands','Chadian':'Chad','French':'French Southern Territories','Togolese':'Togo','Thai':'Thailand','Tadzhik':'Tajikistan','Tokelauan':'Tokelau','East Timorese':'Timor-Leste','Turkmen':'Turkmenistan','Tunisian':'Tunisia','Tongan':'Tonga','Turkish':'Turkey','Trinidadian':'Trinidad and Tobago','Tuvaluan':'Tuvalu','Taiwanese':'Taiwan','Tanzanian':'Tanzania','Ukrainian':'Ukraine','Ugandan':'Uganda','American':'U.S. Minor Outlying Islands','American':'United States','Uruguayan':'Uruguay','Uzbekistani':'Uzbekistan','Italian':'Vatican City','Saint Vincentian':'Saint Vincent and the Grenadines','???':'North Vietnam','Venezuelan':'Venezuela','Virgin Islander':'British Virgin Islands','Virgin Islander':'U.S. Virgin Islands','Vietnamese':'Vietnam','Ni-Vanuatu':'Vanuatu','Wallis and Futuna Islander':'Wallis and Futuna','???':'Wake Island','Samoan':'Samoa','Yemeni':'Yemen','French':'France','South African':'South Africa','Zambian':'Zambia','Zimbabwean':'Zimbabwe'}
)

# %%
drivers.replace({"Carlos Sainz":"Carlos Sainz Jr."}, inplace = True)

# %%
drivers['SUMMARY'] = get_wiki_summary(drivers['DRIVER'])
# Out:
# C:\Users\ricar\anaconda3\lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file C:\Users\ricar\anaconda3\lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# George Russell

# %% [markdown]
# There was an error inputting the information regarding George Russel. This is due to the fact that there are multiple George Russels on Wikipedia. To solve this quickly, we will replace the text with wikipedia's summary.

# %%
drivers.replace({'error':'George William Russell (/rʌsəl/; born 15 February 1998) is a British racing driver currently competing in Formula One for Mercedes. He was the 2018 FIA Formula 2 Champion for ART and the 2017 GP3 Series Champion. Following his Formula 2 championship win, Russell signed for Williams in 2019, making his debut at the 2019 Australian Grand Prix, although he stood in for Lewis Hamilton at Mercedes at the 2020 Sakhir Grand Prix. Russell achieved his first F1 podium with Williams at the 2021 Belgian Grand Prix. He is also part of the Mercedes Young Driver programme.'}, inplace = True)

# %%
drivers['lat'],drivers['long'] = get_coords(drivers['COUNTRY'])

# %%
drivers
# Out:
#     DRIVER_ID              DRIVER         DRIVER_REF DRIVER_CODE        DOB  \
# 0           1      Lewis Hamilton           hamilton         HAM 1985-01-07
# 1           3        Nico Rosberg            rosberg         ROS 1985-06-27
# 2           4     Fernando Alonso             alonso         ALO 1981-07-29
# 3           8      Kimi Raikkonen          raikkonen         RAI 1979-10-17
# 4           9       Robert Kubica             kubica         KUB 1984-12-07
# 5          13        Felipe Massa              massa         MAS 1981-04-25
# 6          16        Adrian Sutil              sutil         SUT 1983-01-11
# 7          18       Jenson Button             button         BUT 1980-01-19
# 8          20    Sebastian Vettel             vettel         VET 1987-07-03
# 9         154     Romain Grosjean           grosjean         GRO 1986-04-17
# 10        155     Kamui Kobayashi          kobayashi         KOB 1986-09-13
# 11        807     Nico Hulkenberg         hulkenberg         HUL 1987-08-19
# 12        813    Pastor Maldonado          maldonado         MAL 1985-03-09
# 13        815        Sergio Perez              perez         PER 1990-01-26
# 14        817    Daniel Ricciardo          ricciardo         RIC 1989-07-01
# 15        818    Jean-Eric Vergne             vergne         VER 1990-04-25
# 16        820         Max Chilton            chilton         CHI 1991-04-21
# 17        821   Esteban Gutierrez          gutierrez         GUT 1991-08-05
# 18        822     Valtteri Bottas             bottas         BOT 1989-08-28
# 19        824       Jules Bianchi      jules_bianchi         BIA 1989-08-03
# 20        825     Kevin Magnussen    kevin_magnussen         MAG 1992-10-05
# 21        826        Daniil Kvyat              kvyat         KVY 1994-04-26
# 22        827      André Lotterer           lotterer         LOT 1981-11-19
# 23        828     Marcus Ericsson           ericsson         ERI 1990-09-02
# 24        829        Will Stevens            stevens         STE 1991-06-28
# 25        830      Max Verstappen     max_verstappen         VER 1997-09-30
# 26        831         Felipe Nasr               nasr         NAS 1992-08-21
# 27        832    Carlos Sainz Jr.              sainz         SAI 1994-09-01
# 28        833       Roberto Merhi              merhi         MER 1991-03-22
# 29        834     Alexander Rossi              rossi         RSS 1991-09-25
# 30        835       Jolyon Palmer      jolyon_palmer         PAL 1991-01-20
# 31        836     Pascal Wehrlein           wehrlein         WEH 1994-10-18
# 32        837        Rio Haryanto           haryanto         HAR 1993-01-22
# 33        838   Stoffel Vandoorne          vandoorne         VAN 1992-03-26
# 34        839        Esteban Ocon               ocon         OCO 1996-09-17
# 35        840        Lance Stroll             stroll         STR 1998-10-29
# 36        841  Antonio Giovinazzi         giovinazzi         GIO 1993-12-14
# 37        842        Pierre Gasly              gasly         GAS 1996-02-07
# 38        843     Brendon Hartley    brendon_hartley         HAR 1989-11-10
# 39        844     Charles Leclerc            leclerc         LEC 1997-10-16
# 40        845     Sergey Sirotkin           sirotkin         SIR 1995-08-27
# 41        846        Lando Norris             norris         NOR 1999-11-13
# 42        847      George Russell            russell         RUS 1998-02-15
# 43        848     Alexander Albon              albon         ALB 1996-03-23
# 44        849     Nicholas Latifi             latifi         LAT 1995-06-29
# 45        850   Pietro Fittipaldi  pietro_fittipaldi         FIT 1996-06-25
# 46        851         Jack Aitken             aitken         AIT 1995-09-23
# 47        852        Yuki Tsunoda            tsunoda         TSU 2000-05-11
# 48        853      Nikita Mazepin            mazepin         MAZ 1999-03-02
# 49        854     Mick Schumacher    mick_schumacher         MSC 1999-03-22
# 50        855         Guanyu Zhou               zhou         ZHO 1999-05-30
#
#       NATIONALITY         COUNTRY  \
# 0         British  United Kingdom
# 1          German         Germany
# 2         Spanish           Spain
# 3         Finnish         Finland
# 4          Polish          Poland
# 5       Brazilian          Brazil
# 6          German         Germany
# 7         British  United Kingdom
# 8          German         Germany
# 9          French          France
# 10       Japanese           Japan
# 11         German         Germany
# 12     Venezuelan       Venezuela
# 13        Mexican          Mexico
# 14     Australian       Australia
# 15         French          France
# 16        British  United Kingdom
# 17        Mexican          Mexico
# 18        Finnish         Finland
# 19         French          France
# 20         Danish         Denmark
# 21        Russian          Russia
# 22         German         Germany
# 23        Swedish          Sweden
# 24        British  United Kingdom
# 25          Dutch     Netherlands
# 26      Brazilian          Brazil
# 27        Spanish           Spain
# 28        Spanish           Spain
# 29       American   United States
# 30        British  United Kingdom
# 31         German         Germany
# 32     Indonesian       Indonesia
# 33        Belgian         Belgium
# 34         French          France
# 35       Canadian          Canada
# 36        Italian    Vatican City
# 37         French          France
# 38  New Zealander     New Zealand
# 39     Monegasque          Monaco
# 40        Russian          Russia
# 41        British  United Kingdom
# 42        British  United Kingdom
# 43           Thai        Thailand
# 44       Canadian          Canada
# 45      Brazilian          Brazil
# 46        British  United Kingdom
# 47       Japanese           Japan
# 48        Russian          Russia
# 49         German         Germany
# 50        Chinese           China
#
#                                               SUMMARY  \
# 0   Sir Lewis Carl Davidson Hamilton  (born 7 Janu...
# 1   Nico Erik Rosberg (born 27 June 1985) is a Ger...
# 2   Fernando Alonso Díaz (Spanish pronunciation: [...
# 3   Kimi-Matias Räikkönen (Finnish pronunciation: ...
# 4   Robert Józef Kubica (Polish pronunciation: [ˈr...
# 5   Felipe Massa (Portuguese pronunciation: [fiˈli...
# 6   Adrian Sutil (German pronunciation: [ˈadɾjan z...
# 7   Jenson Alexander Lyons Button  (born 19 Januar...
# 8   Sebastian Vettel (German pronunciation: [zeˈba...
# 9   Romain Grosjean (French: [ʁɔmɛ̃ ɡʁoʒɑ̃]; born ...
# 10  Kamui Kobayashi (小林 可夢偉, Kobayashi Kamui, born...
# 11  Nicolas Hülkenberg (German pronunciation: [ˈni...
# 12  Pastor Rafael Maldonado Motta (Spanish pronunc...
# 13  Sergio Michel "Checo" Pérez Mendoza (Spanish: ...
# 14  Daniel Joseph Ricciardo  ( "Ricardo"; born 1 J...
# 15  Jean-Éric Vergne (born 25 April 1990), also kn...
# 16  Maximilian Alexander Chilton (born 21 April 19...
# 17  Esteban Manuel Gutiérrez Gutiérrez (Spanish pr...
# 18  Valtteri Viktor Bottas (Finnish pronunciation:...
# 19  Jules Lucien André Bianchi (French pronunciati...
# 20  Kevin Jan Magnussen (born 5 October 1992) is a...
# 21  Daniil Vyacheslavovich Kvyat (born 26 April 19...
# 22  André Lotterer (born 19 November 1981) is a Ge...
# 23  Marcus Thorbjörn Ericsson (Swedish pronunciati...
# 24  William Stevens (born 28 June 1991) is a Briti...
# 25  Max Emilian Verstappen (born 30 September 1997...
# 26  Luiz Felipe de Oliveira Nasr (born 21 August 1...
# 27  Carlos Sainz Vázquez de Castro (Spanish pronun...
# 28  Roberto Merhi Muntan (born 22 March 1991) is a...
# 29  Alexander Michael Rossi (born September 25, 19...
# 30  Jolyon Palmer (born 20 January 1991) is a Brit...
# 31  Pascal Wehrlein (born 18 October 1994) is a Ge...
# 32  Rio Haryanto (born 22 January 1993) is an Indo...
# 33  Stoffel Vandoorne (born 26 March 1992) is a Be...
# 34  Esteban José Jean-Pierre Ocon-Khelfane (born 1...
# 35  Lance Strulovitch, (born 29 October 1998) bett...
# 36  Antonio Maria Giovinazzi (Italian pronunciatio...
# 37  Pierre Gasly (French pronunciation: ​[pjɛʁ ɡas...
# 38  Brendon Hartley (born 10 November 1989) is a N...
# 39  Charles Marc Hervé Perceval Leclerc (French pr...
# 40  Sergey Olegovich Sirotkin (Russian: Серге́й Ол...
# 41  Lando Norris (; born 13 November 1999) is a Br...
# 42  George William Russell (/rʌsəl/; born 15 Febru...
# 43  Alexander Albon Ansusinha (Thai: อเล็กซานเดอร์...
# 44  Nicholas Daniel Latifi (born 29 June 1995) is ...
# 45  Pietro Fittipaldi da Cruz (born 25 June 1996) ...
# 46  Jack Aitken (Korean: 한세용, Han Se-yong; born 23...
# 47  Yuki Tsunoda (Japanese: 角田 裕毅, Tsunoda Yūki; b...
# 48  Nikita Dmitryevich Mazepin (Russian: Ники́та Д...
# 49  Mick Schumacher (German pronunciation: [ˈmɪk ˈ...
# 50  Zhou Guanyu (Chinese: 周冠宇; pinyin: Zhōu Guànyǔ...
#
#                                                   lat  \
# 0                                                  55
# 1                                                  51
# 2                                                  40
# 3                                                  64
# 4                                                  52
# 5                                                 -10
# 6                                                  51
# 7                                                  55
# 8                                                  51
# 9                                                  47
# 10                                                 36
# 11                                                 51
# 12                                                  7
# 13                                                 23
# 14                                                -25
# 15                                                 47
# 16                                                 55
# 17                                                 23
# 18                                                 64
# 19                                                 47
# 20                                                 56
# 21                                 55.802479274214974
# 22                                                 51
# 23                                                 63
# 24                                                 55
# 25                                  52.36463903490765
# 26                                                -10
# 27                                                 40
# 28                                                 40
# 29                                                 40
# 30                                                 55
# 31                                                 51
# 32                                                 -5
# 33  50.8333333300000020926745492033660411834716796875
# 34                                                 47
# 35                                                 60
# 36   41.902500000000003410605131648480892181396484375
# 37                                                 47
# 38                                                -42
# 39   43.731111110000000508080120198428630828857421875
# 40                                 55.802479274214974
# 41                                                 55
# 42                                                 55
# 43                                                 15
# 44                                                 60
# 45                                                -10
# 46                                                 55
# 47                                                 36
# 48                                 55.802479274214974
# 49                                                 51
# 50                                                 35
#
#                                                  long
# 0                                                  -3
# 1                                                   9
# 2                                                  -4
# 3                                                  26
# 4                                                  20
# 5                                                 -52
# 6                                                   9
# 7                                                  -3
# 8                                                   9
# 9                                                   2
# 10                                                138
# 11                                                  9
# 12                                                -65
# 13                                               -102
# 14                                                133
# 15                                                  2
# 16                                                 -3
# 17                                               -102
# 18                                                 26
# 19                                                  2
# 20                                                 10
# 21                                 37.592885102145694
# 22                                                  9
# 23                                                 16
# 24                                                 -3
# 25                                  4.908115191408701
# 26                                                -52
# 27                                                 -4
# 28                                                 -4
# 29                                               -100
# 30                                                 -3
# 31                                                  9
# 32                                                120
# 33                                                  4
# 34                                                  2
# 35                                               -110
# 36  12.4525000000000005684341886080801486968994140625
# 37                                                  2
# 38                                                173
# 39  7.41999999999999992894572642398998141288757324...
# 40                                 37.592885102145694
# 41                                                 -3
# 42                                                 -3
# 43                                                101
# 44                                               -110
# 45                                                -52
# 46                                                 -3
# 47                                                138
# 48                                 37.592885102145694
# 49                                                  9
# 50                                                103

# %% [markdown]
# Manually input the right lat & long values for Russia

# %%
drivers
# Out:
#     DRIVER_ID              DRIVER         DRIVER_REF DRIVER_CODE        DOB  \
# 0           1      Lewis Hamilton           hamilton         HAM 1985-01-07
# 1           3        Nico Rosberg            rosberg         ROS 1985-06-27
# 2           4     Fernando Alonso             alonso         ALO 1981-07-29
# 3           8      Kimi Raikkonen          raikkonen         RAI 1979-10-17
# 4           9       Robert Kubica             kubica         KUB 1984-12-07
# 5          13        Felipe Massa              massa         MAS 1981-04-25
# 6          16        Adrian Sutil              sutil         SUT 1983-01-11
# 7          18       Jenson Button             button         BUT 1980-01-19
# 8          20    Sebastian Vettel             vettel         VET 1987-07-03
# 9         154     Romain Grosjean           grosjean         GRO 1986-04-17
# 10        155     Kamui Kobayashi          kobayashi         KOB 1986-09-13
# 11        807     Nico Hulkenberg         hulkenberg         HUL 1987-08-19
# 12        813    Pastor Maldonado          maldonado         MAL 1985-03-09
# 13        815        Sergio Perez              perez         PER 1990-01-26
# 14        817    Daniel Ricciardo          ricciardo         RIC 1989-07-01
# 15        818    Jean-Eric Vergne             vergne         VER 1990-04-25
# 16        820         Max Chilton            chilton         CHI 1991-04-21
# 17        821   Esteban Gutierrez          gutierrez         GUT 1991-08-05
# 18        822     Valtteri Bottas             bottas         BOT 1989-08-28
# 19        824       Jules Bianchi      jules_bianchi         BIA 1989-08-03
# 20        825     Kevin Magnussen    kevin_magnussen         MAG 1992-10-05
# 21        826        Daniil Kvyat              kvyat         KVY 1994-04-26
# 22        827      André Lotterer           lotterer         LOT 1981-11-19
# 23        828     Marcus Ericsson           ericsson         ERI 1990-09-02
# 24        829        Will Stevens            stevens         STE 1991-06-28
# 25        830      Max Verstappen     max_verstappen         VER 1997-09-30
# 26        831         Felipe Nasr               nasr         NAS 1992-08-21
# 27        832    Carlos Sainz Jr.              sainz         SAI 1994-09-01
# 28        833       Roberto Merhi              merhi         MER 1991-03-22
# 29        834     Alexander Rossi              rossi         RSS 1991-09-25
# 30        835       Jolyon Palmer      jolyon_palmer         PAL 1991-01-20
# 31        836     Pascal Wehrlein           wehrlein         WEH 1994-10-18
# 32        837        Rio Haryanto           haryanto         HAR 1993-01-22
# 33        838   Stoffel Vandoorne          vandoorne         VAN 1992-03-26
# 34        839        Esteban Ocon               ocon         OCO 1996-09-17
# 35        840        Lance Stroll             stroll         STR 1998-10-29
# 36        841  Antonio Giovinazzi         giovinazzi         GIO 1993-12-14
# 37        842        Pierre Gasly              gasly         GAS 1996-02-07
# 38        843     Brendon Hartley    brendon_hartley         HAR 1989-11-10
# 39        844     Charles Leclerc            leclerc         LEC 1997-10-16
# 40        845     Sergey Sirotkin           sirotkin         SIR 1995-08-27
# 41        846        Lando Norris             norris         NOR 1999-11-13
# 42        847      George Russell            russell         RUS 1998-02-15
# 43        848     Alexander Albon              albon         ALB 1996-03-23
# 44        849     Nicholas Latifi             latifi         LAT 1995-06-29
# 45        850   Pietro Fittipaldi  pietro_fittipaldi         FIT 1996-06-25
# 46        851         Jack Aitken             aitken         AIT 1995-09-23
# 47        852        Yuki Tsunoda            tsunoda         TSU 2000-05-11
# 48        853      Nikita Mazepin            mazepin         MAZ 1999-03-02
# 49        854     Mick Schumacher    mick_schumacher         MSC 1999-03-22
# 50        855         Guanyu Zhou               zhou         ZHO 1999-05-30
#
#       NATIONALITY         COUNTRY  \
# 0         British  United Kingdom
# 1          German         Germany
# 2         Spanish           Spain
# 3         Finnish         Finland
# 4          Polish          Poland
# 5       Brazilian          Brazil
# 6          German         Germany
# 7         British  United Kingdom
# 8          German         Germany
# 9          French          France
# 10       Japanese           Japan
# 11         German         Germany
# 12     Venezuelan       Venezuela
# 13        Mexican          Mexico
# 14     Australian       Australia
# 15         French          France
# 16        British  United Kingdom
# 17        Mexican          Mexico
# 18        Finnish         Finland
# 19         French          France
# 20         Danish         Denmark
# 21        Russian          Russia
# 22         German         Germany
# 23        Swedish          Sweden
# 24        British  United Kingdom
# 25          Dutch     Netherlands
# 26      Brazilian          Brazil
# 27        Spanish           Spain
# 28        Spanish           Spain
# 29       American   United States
# 30        British  United Kingdom
# 31         German         Germany
# 32     Indonesian       Indonesia
# 33        Belgian         Belgium
# 34         French          France
# 35       Canadian          Canada
# 36        Italian    Vatican City
# 37         French          France
# 38  New Zealander     New Zealand
# 39     Monegasque          Monaco
# 40        Russian          Russia
# 41        British  United Kingdom
# 42        British  United Kingdom
# 43           Thai        Thailand
# 44       Canadian          Canada
# 45      Brazilian          Brazil
# 46        British  United Kingdom
# 47       Japanese           Japan
# 48        Russian          Russia
# 49         German         Germany
# 50        Chinese           China
#
#                                               SUMMARY  \
# 0   Sir Lewis Carl Davidson Hamilton  (born 7 Janu...
# 1   Nico Erik Rosberg (born 27 June 1985) is a Ger...
# 2   Fernando Alonso Díaz (Spanish pronunciation: [...
# 3   Kimi-Matias Räikkönen (Finnish pronunciation: ...
# 4   Robert Józef Kubica (Polish pronunciation: [ˈr...
# 5   Felipe Massa (Portuguese pronunciation: [fiˈli...
# 6   Adrian Sutil (German pronunciation: [ˈadɾjan z...
# 7   Jenson Alexander Lyons Button  (born 19 Januar...
# 8   Sebastian Vettel (German pronunciation: [zeˈba...
# 9   Romain Grosjean (French: [ʁɔmɛ̃ ɡʁoʒɑ̃]; born ...
# 25                                  52.36463903490765
# 26                                                -10
# 27                                                 40
# 28                                                 40
# 29                                                 40
# 30                                                 55
# 31                                                 51
# 32                                                 -5
# 33  50.8333333300000020926745492033660411834716796875
# 34                                                 47
# 35                                                 60
# 36   41.902500000000003410605131648480892181396484375
# 37                                                 47
# 38                                                -42
# 39   43.731111110000000508080120198428630828857421875
# 40                                 55.802479274214974
# 41                                                 55
# 42                                                 55
# 43                                                 15
# 44                                                 60
# 45                                                -10
# 46                                                 55
# 47                                                 36
# 48                                 55.802479274214974
# 49                                                 51
# 50                                                 35
#
#                                                  long
# 0                                                  -3
# 1                                                   9
# 2                                                  -4
# 3                                                  26
# 4                                                  20
# 5                                                 -52
# 6                                                   9
# 7                                                  -3
# 8                                                   9
# 9                                                   2
# 10                                                138
# 11                                                  9
# 12                                                -65
# 13                                               -102
# 14                                                133
# 15                                                  2
# 16                                                 -3
# 17                                               -102
# 18                                                 26
# 19                                                  2
# 20                                                 10
# 21                                 37.592885102145694
# 22                                                  9
# 23                                                 16
# 24                                                 -3
# 25                                  4.908115191408701
# 26                                                -52
# 27                                                 -4
# 28                                                 -4
# 29                                               -100
# 30                                                 -3
# 31                                                  9
# 32                                                120
# 33                                                  4
# 34                                                  2
# 35                                               -110
# 36  12.4525000000000005684341886080801486968994140625
# 37                                                  2
# 38                                                173
# 39  7.41999999999999992894572642398998141288757324...
# 40                                 37.592885102145694
# 41                                                 -3
# 42                                                 -3
# 43                                                101
# 44                                               -110
# 45                                                -52
# 46                                                 -3
# 47                                                138
# 48                                 37.592885102145694
# 49                                                  9
# 50                                                103

# %% [markdown]
# ## Constructor information

# %%
constructors
# Out:
#     constructorId constructorRef            name nationality  \
# 0               1        mclaren         McLaren     British
# 1               3       williams        Williams     British
# 2               4        renault         Renault      French
# 3               5     toro_rosso      Toro Rosso     Italian
# 4               6        ferrari         Ferrari     Italian
# 5               9       red_bull        Red Bull    Austrian
# 6              10    force_india     Force India      Indian
# 7              15         sauber          Sauber       Swiss
# 8              51           alfa      Alfa Romeo       Swiss
# 9             117   aston_martin    Aston Martin     British
# 10            131       mercedes        Mercedes      German
# 11            206       marussia        Marussia     Russian
# 12            208       lotus_f1        Lotus F1     British
# 13            209          manor  Manor Marussia     British
# 14            210           haas    Haas F1 Team    American
# 15            211   racing_point    Racing Point     British
# 16            213     alphatauri      AlphaTauri     Italian
# 17            214         alpine  Alpine F1 Team      French
#
#                                                   url         country  \
# 0                http://en.wikipedia.org/wiki/McLaren  United Kingdom
# 1   http://en.wikipedia.org/wiki/Williams_Grand_Pr...  United Kingdom
# 2   http://en.wikipedia.org/wiki/Renault_in_Formul...          France
# 3    http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso           Italy
# 4       http://en.wikipedia.org/wiki/Scuderia_Ferrari           Italy
# 5        http://en.wikipedia.org/wiki/Red_Bull_Racing         Austria
# 6   http://en.wikipedia.org/wiki/Racing_Point_Forc...           India
# 7                 http://en.wikipedia.org/wiki/Sauber     Switzerland
# 8   http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...     Switzerland
# 9   http://en.wikipedia.org/wiki/Aston_Martin_in_F...  United Kingdom
# 10  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...         Germany
# 11           http://en.wikipedia.org/wiki/Marussia_F1          Russia
# 12              http://en.wikipedia.org/wiki/Lotus_F1  United Kingdom
# 13      http://en.wikipedia.org/wiki/Manor_Motorsport  United Kingdom
# 14          http://en.wikipedia.org/wiki/Haas_F1_Team   United States
# 15  http://en.wikipedia.org/wiki/Racing_Point_F1_Team  United Kingdom
# 16   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri           Italy
# 17        http://en.wikipedia.org/wiki/Alpine_F1_Team          France
#
#                                                   lat  \
# 0                                                  55
# 1                                                  55
# 2                                                  47
# 3                                                  43
# 4                                                  43
# 5   47.3333333300000020926745492033660411834716796875
# 6                                                  21
# 7   46.8333333300000020926745492033660411834716796875
# 8   46.8333333300000020926745492033660411834716796875
# 9                                                  55
# 10                                                 51
# 11                                 55.802479274214974
# 12                                                 55
# 13                                                 55
# 14                                                 40
# 15                                                 55
# 16                                                 43
# 17                                                 47
#
#                                                  long  \
# 0                                                  -3
# 1                                                  -3
# 2                                                   2
# 3                                                  12
# 4                                                  12
# 5   13.3333333300000003163177098031155765056610107...
# 6                                                  78
# 7   8.33333333000000031631770980311557650566101074...
# 8   8.33333333000000031631770980311557650566101074...
# 9                                                  -3
# 10                                                  9
# 11                                 37.592885102145694
# 12                                                 -3
# 13                                                 -3
# 14                                               -100
# 15                                                 -3
# 16                                                 12
# 17                                                  2
#
#                                               summary
# 0   McLaren Racing Limited is a British motor raci...
# 1                                               error
# 2   Groupe Renault (UK:  REN-oh, US:  rə-NAWLT, rə...
# 3   Scuderia Toro Rosso, commonly known as Toro Ro...
# 4   Ferrari S.p.A. (; Italian: [ferˈraːri]) is an ...
# 5   Red Bull is a brand of energy drinks sold by A...
# 6   Force India Formula One Team Limited, commonly...
# 7   Sauber Motorsport AG is a Swiss motorsport eng...
# 8   Alfa Romeo Automobiles S.p.A. (Italian: [ˈalfa...
# 9   Aston Martin Lagonda Global Holdings PLC is an...
# 10                                              error
# 11  Marussia Motors (Russian: Маруся pronounced [m...
# 12  Lotus F1 Team was a British Formula One racing...
# 13  The Marussia F1 Team (subsequently Manor Marus...
# 14  Haas Formula LLC, competing as Haas F1 Team, i...
# 15  Racing Point F1 Team, which competed as BWT Ra...
# 16                                              error
# 17  Alpine F1 Team, competing as BWT Alpine F1 Tea...

# %%
constructors['country'] = constructors['nationality'].replace({'Andorran':'Andorra','Emirati':'United Arab Emirates','Afghan':'Afghanistan','Antiguan, Barbudan':'Antigua and Barbuda','Anguillian':'Anguilla','Albanian':'Albania','Armenian':'Armenia','Dutch':'Netherlands Antilles','Angolan':'Angola','???':'Antarctica','Argentinean':'Argentina','American Samoan':'American Samoa','Austrian':'Austria','Australian':'Australia','Aruban':'Aruba','Swedish':'Åland Islands','Azerbaijani':'Azerbaijan','Bosnian, Herzegovinian':'Bosnia and Herzegovina','Barbadian':'Barbados','Bangladeshi':'Bangladesh','Belgian':'Belgium','Burkinabe':'Burkina Faso','Bulgarian':'Bulgaria','Bahraini':'Bahrain','
)
constructors
# Out:
#     constructorId constructorRef            name nationality  \
# 0               1        mclaren         McLaren     British
# 1               3       williams        Williams     British
# 2               4        renault         Renault      French
# 3               5     toro_rosso      Toro Rosso     Italian
# 4               6        ferrari         Ferrari     Italian
# 5               9       red_bull        Red Bull    Austrian
# 6              10    force_india     Force India      Indian
# 7              15         sauber          Sauber       Swiss
# 8              51           alfa      Alfa Romeo       Swiss
# 9             117   aston_martin    Aston Martin     British
# 10            131       mercedes        Mercedes      German
# 11            206       marussia        Marussia     Russian
# 12            208       lotus_f1        Lotus F1     British
# 13            209          manor  Manor Marussia     British
# 14            210           haas    Haas F1 Team    American
# 15            211   racing_point    Racing Point     British
# 16            213     alphatauri      AlphaTauri     Italian
# 17            214         alpine  Alpine F1 Team      French
#
#                                                   url         country  \
# 0                http://en.wikipedia.org/wiki/McLaren  United Kingdom
# 1   http://en.wikipedia.org/wiki/Williams_Grand_Pr...  United Kingdom
# 2   http://en.wikipedia.org/wiki/Renault_in_Formul...          France
# 3    http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso           Italy
# 4       http://en.wikipedia.org/wiki/Scuderia_Ferrari           Italy
# 5        http://en.wikipedia.org/wiki/Red_Bull_Racing         Austria
# 6   http://en.wikipedia.org/wiki/Racing_Point_Forc...           India
# 7                 http://en.wikipedia.org/wiki/Sauber     Switzerland
# 8   http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...     Switzerland
# 9   http://en.wikipedia.org/wiki/Aston_Martin_in_F...  United Kingdom
# 10  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...         Germany
# 11           http://en.wikipedia.org/wiki/Marussia_F1          Russia
# 12              http://en.wikipedia.org/wiki/Lotus_F1  United Kingdom
# 13      http://en.wikipedia.org/wiki/Manor_Motorsport  United Kingdom
# 14          http://en.wikipedia.org/wiki/Haas_F1_Team   United States
# 15  http://en.wikipedia.org/wiki/Racing_Point_F1_Team  United Kingdom
# 16   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri           Italy
# 17        http://en.wikipedia.org/wiki/Alpine_F1_Team          France
#
#                                                   lat  \
# 0                                                  55
# 1                                                  55
# 2                                                  47
# 3                                                  43
# 4                                                  43
# 5   47.3333333300000020926745492033660411834716796875
# 6                                                  21
# 7   46.8333333300000020926745492033660411834716796875
# 8   46.8333333300000020926745492033660411834716796875
# 9                                                  55
# 10                                                 51
# 11                                 55.802479274214974
# 12                                                 55
# 13                                                 55
# 14                                                 40
# 15                                                 55
# 16                                                 43
# 17                                                 47
#
#                                                  long  \
# 0                                                  -3
# 1                                                  -3
# 2                                                   2
# 3                                                  12
# 4                                                  12
# 5   13.3333333300000003163177098031155765056610107...
# 6                                                  78
# 7   8.33333333000000031631770980311557650566101074...
# 8   8.33333333000000031631770980311557650566101074...
# 9                                                  -3
# 10                                                  9
# 11                                 37.592885102145694
# 12                                                 -3
# 13                                                 -3
# 14                                               -100
# 15                                                 -3
# 16                                                 12
# 17                                                  2
#
#                                               summary
# 0   McLaren Racing Limited is a British motor raci...
# 1                                               error
# 2   Groupe Renault (UK:  REN-oh, US:  rə-NAWLT, rə...
# 3   Scuderia Toro Rosso, commonly known as Toro Ro...
# 4   Ferrari S.p.A. (; Italian: [ferˈraːri]) is an ...
# 5   Red Bull is a brand of energy drinks sold by A...
# 6   Force India Formula One Team Limited, commonly...
# 7   Sauber Motorsport AG is a Swiss motorsport eng...
# 8   Alfa Romeo Automobiles S.p.A. (Italian: [ˈalfa...
# 9   Aston Martin Lagonda Global Holdings PLC is an...
# 10                                              error
# 11  Marussia Motors (Russian: Маруся pronounced [m...
# 12  Lotus F1 Team was a British Formula One racing...
# 13  The Marussia F1 Team (subsequently Manor Marus...
# 14  Haas Formula LLC, competing as Haas F1 Team, i...
# 15  Racing Point F1 Team, which competed as BWT Ra...
# 16                                              error
# 17  Alpine F1 Team, competing as BWT Alpine F1 Tea...

# %%
constructors['lat'],constructors['long'] = get_coords(constructors['country'])

# %%
constructors['summary'] = get_wiki_summary(constructors['name'])
# Out:
# C:\Users\ricar\anaconda3\lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file C:\Users\ricar\anaconda3\lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')

# %% [markdown]
# ## Circuit information

# %%
circuits
# Out:
#     circuitId                                  name      location  \
# 0           1        Albert Park Grand Prix Circuit     Melbourne
# 1           2          Sepang International Circuit  Kuala Lumpur
# 2           3         Bahrain International Circuit        Sakhir
# 3           4        Circuit de Barcelona-Catalunya      Montmeló
# 4           5                         Istanbul Park      Istanbul
# 5           6                     Circuit de Monaco   Monte-Carlo
# 6           7             Circuit Gilles Villeneuve      Montreal
# 7           9                   Silverstone Circuit   Silverstone
# 8          10                        Hockenheimring    Hockenheim
# 9          11                           Hungaroring      Budapest
# 10         13          Circuit de Spa-Francorchamps           Spa
# 11         14          Autodromo Nazionale di Monza         Monza
# 12         15             Marina Bay Street Circuit    Marina Bay
# 13         17        Shanghai International Circuit      Shanghai
# 14         18            Autódromo José Carlos Pace     São Paulo
# 15         20                           Nürburgring       Nürburg
# 16         21         Autodromo Enzo e Dino Ferrari         Imola
# 17         22                        Suzuka Circuit        Suzuka
# 18         24                    Yas Marina Circuit     Abu Dhabi
# 19         32          Autódromo Hermanos Rodríguez   Mexico City
# 20         34                   Circuit Paul Ricard  Le Castellet
# 21         39                Circuit Park Zandvoort     Zandvoort
# 22         69               Circuit of the Americas        Austin
# 23         70                         Red Bull Ring     Spielberg
# 24         71                        Sochi Autodrom         Sochi
# 25         73                     Baku City Circuit          Baku
# 26         75    Autódromo Internacional do Algarve      Portimão
# 27         76  Autodromo Internazionale del Mugello       Mugello
# 28         77               Jeddah Corniche Circuit        Jeddah
# 29         78          Losail International Circuit     Al Daayen
# 30         79         Miami International Autodrome         Miami
#
#           country     alt                                                url  \
# 0       Australia    10.0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1        Malaysia    18.0  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2         Bahrain     7.0  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3           Spain   109.0  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4          Turkey   130.0         http://en.wikipedia.org/wiki/Istanbul_Park
# 5          Monaco     7.0     http://en.wikipedia.org/wiki/Circuit_de_Monaco
#
# 9   19.2511111100000000817544787423685193061828613...
# 10   5.9713888900000000603540684096515178680419921875
# 11  9.28944444000000046912646212149411439895629882...
# 12  103.863849999999999340616341214627027511596679...
# 13     121.219722219999994194949977099895477294921875
# 14  -46.697222220000000447726051788777112960815429...
# 15                                  7.045744986271267
# 16  11.7133333299999993215578797389753162860870361...
# 17  136.540555560000001378284650854766368865966796875
# 18   54.603055560000001378284650854766368865966796875
# 19  -99.092500000000001136868377216160297393798828125
# 20  5.79166666999999968368229019688442349433898925...
# 21  4.54092221999999967607664075330831110477447509...
# 22    -97.6411111099999970974749885499477386474609375
# 23  14.7647222199999994529662217246368527412414550...
# 24  39.9682710000000014360921340994536876678466796875
# 25    49.85333332999999811363522894680500030517578125
# 26  -8.6319999999999996731503415503539144992828369...
# 27  11.3719444400000000428008206654340028762817382...
# 28  39.1044444400000017481033864896744489669799804...
# 29  51.4541666699999993284109223168343305587768554...
# 30                                   -80.231329321313
#
#                                               summary
# 0   The Albert Park Circuit is a motorsport street...
# 1   The Sepang International Circuit (Malay: Litar...
# 2   The Bahrain International Circuit (Arabic: حلب...
# 3   The Circuit de Barcelona-Catalunya (Catalan pr...
# 4   Intercity Istanbul Park (Turkish: İstanbul Par...
# 5   Circuit de Monaco is a 3.337 km (2.074 mi) str...
# 6   The Circuit Gilles Villeneuve (also spelled Ci...
# 7   Silverstone Circuit is a motor racing circuit ...
# 8   The Hockenheimring Baden-Württemberg (German: ...
# 9   The Hungaroring is a 4.381 km (2.722 mi) motor...
# 10  The Circuit de Spa-Francorchamps (French pronu...
# 11  The Monza Circuit (Italian: Autodromo Nazional...
# 12  The Marina Bay Street Circuit (otherwise known...
# 13  The Shanghai International Circuit (simplified...
# 14  The Autódromo José Carlos Pace, better known a...
# 15  The Nürburgring is a 150,000 person capacity m...
# 16  The Autodromo Internazionale Enzo e Dino Ferra...
# 17  The Suzuka International Racing Course (鈴鹿国際レー...
# 18  The Yas Marina Circuit (Arabic: حلبة مرسى ياس)...
# 19  The Autódromo Hermanos Rodríguez is a 4.304 km...
# 20  The Circuit Paul Ricard (French pronunciation:...
# 21  Circuit Zandvoort (Dutch pronunciation: [sɪrˈk...
# 22  Circuit of the Americas (COTA) is a Grade 1 FI...
# 23  The Red Bull Ring is a motorsport race track i...
# 24  The Sochi Autodrom (Russian: Сочи Автодром), p...
# 25  The Baku City Circuit (Azerbaijani: Bakı Şəhər...
# 26  The Algarve International Circuit (Portuguese:...
# 27  Mugello Circuit (Autodromo Internazionale del ...
# 28  The Jeddah Corniche Circuit (Arabic: حلبة كورن...
# 29  Losail International Circuit (Arabic: حلبة لوس...
# 30  The Miami International Autodrome is a purpose...

# %% [markdown]
# There is an issue with our coordinates. Thus, we will leverage on Wikipedia module's functionality to get new coordinates.

# %%
circuits.drop(columns=['lat','lng'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12792/1158200794.py in <module>
# ----> 1 circuits.drop(columns=['lat','lng'],inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['lng'] not found in axis"

# %%
circuits['lat'], circuits['long'] = get_coords(circuits['name'])

# %% [markdown]
# We can extend the information we display to the map's users by adding a spoiler feature within the popup of the map, containing Wikipedia's summary for the entry.

# %%
circuits['summary'] = get_wiki_summary(circuits['name'])

# %%
circuits

# %% [markdown]
# ## Generating the map

# %%
generate_map(circuits, drivers, constructors)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ce0cf21f40055b07d1a69c8bd86b3c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ce0cf21f40055b07d1a69c8bd86b3c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9ce0cf21f40055b07d1a69c8bd86b3c4 = L.map(
#                 &quot;map_9ce0cf21f40055b07d1a69c8bd86b3c4&quot;,
#                 {
#                     center: [38.73241897525329, -9.160338893258317],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6cba290ba4c9c7f183c2ced63f1ea7d6 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9ce0cf21f40055b07d1a69c8bd86b3c4);
#
#
#             var marker_de54198381e04aa6c595d19e989bfe72 = L.marker(
#                 [-37.84972222, 144.96833333],
#                 {&quot;radius&quot;: 3}
#             ).addTo(map_9ce0cf21f40055b07d1a69c8bd86b3c4);
#
#
#             var icon_20a5978283815a372e2d106890c6e4d6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_de54198381e04aa6c595d19e989bfe72.setIcon(icon_20a5978283815a372e2d106890c6e4d6);
#
#
#         var popup_6f3fdfb12301bd601f5db13d62d9a29c = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#             var i_frame_ec50db76435b486d1d49d21599ce82a2 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_6f3fdfb12301bd601f5db13d62d9a29c.setContent(i_frame_ec50db76435b486d1d49d21599ce82a2);
#
#
#         marker_de54198381e04aa6c595d19e989bfe72.bindPopup(popup_6f3fdfb12301bd601f5db13d62d9a29c)
#         ;
#
#
#
#
#             marker_de54198381e04aa6c595d19e989bfe72.bindTooltip(
#                 `&lt;div&gt;
#                      Albert Park Grand Prix Circuit
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8380803d18e90e71022a71bf3414fab0 = L.marker(
#                 [2.76055556, 101.7375],
#                 {&quot;radius&quot;: 3}
#             ).addTo(map_9ce0cf21f40055b07d1a69c8bd86b3c4);
#
#
#             var icon_20d1fb5cc0db7bed36b7ebe85b32a03a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8380803d18e90e71022a71bf3414fab0.setIcon(icon_20d1fb5cc0db7bed36b7ebe85b32a03a);
#
#
#         var popup_f67d66bdff0ef99755ea38b3ea683b88 = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#             var i_frame_b6e3ae5fe5e12631a787c8b3c1ec28f5 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_f67d66bdff0ef99755ea38b3ea683b88.setContent(i_frame_b6e3ae5fe5e12631a787c8b3c1ec28f5);
#
#
#         marker_8380803d18e90e71022a71bf3414fab0.bindPopup(popup_f67d66bdff0ef99755ea38b3ea683b88)
#         ;
#
#
#
#
#             marker_8380803d18e90e71022a71bf3414fab0.bindTooltip(
#                 `&lt;div&gt;
#                      Sepang International Circuit
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9d9d20b0a5debbbf9deeab37f7cab188 = L.marker(
#                 [26.0325, 50.51055556],
#                 {&quot;radius&quot;: 3}
#             ).addTo(map_9ce0cf21f40055b07d1a69c8bd86b3c4);
#
#
#             var icon_73c10015d5210f2b0557bd67369e5c7b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9d9d20b0a5debbbf9deeab37f7cab188.setIcon(icon_73c10015d5210f2b0557bd67369e5c7b);
#
#
#         var popup_ce2511ec0342ae75d9c43f81c62820f4 = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#             var i_frame_74e4463cf7303eb676a0836bedbbf41a = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_ce2511ec0342ae75d9c43f81c6282

# %%
circuits
